# %% [markdown]
# ## 라이브러리 import

# %%
import os
import math
import copy
import numpy as np
import tensorflow as tf

from glob import glob
from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize

from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import VGG19

# %%
backbones = {"vgg16": VGG16, "vgg19": VGG19}

# %%
DEFAULT_SKIP_CONNECTIONS = {
    'vgg16':            ('block5_conv3', 'block4_conv3', 'block3_conv3', 'block2_conv2', 'block1_conv2',
                         'block5_pool', 'block4_pool', 'block3_pool', 'block2_pool', 'block1_pool'),
    'vgg19':            ('block5_conv4', 'block4_conv4', 'block3_conv4', 'block2_conv2', 'block1_conv2',
                         'block5_pool', 'block4_pool', 'block3_pool', 'block2_pool', 'block1_pool')}

# %% [markdown]
# ## 데이터 전처리

# %%
def build_augmentation(is_train=True):
    if is_train:    # 훈련용 데이터일 경우
        return Compose([
            HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
            RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                min_max_height=(300, 370),
                w2h_ratio=370/1242,
                height=224,
                width=224,
                p=0.5
            ),
            Resize(              # 입력이미지를 224X224로 resize
                width=224,
                height=224
            )
        ])
    
    return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
        Resize(
            width=224,
            height=224
        )
    ])

# %%
class KittiGenerator(tf.keras.utils.Sequence):
    '''
    KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
    우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
    '''
    def __init__(self, 
                 dir_path,
                 batch_size=16,
                 img_size=(224, 224, 3),
                 output_size=(224, 224),
                 is_train=True,
                 augmentation=None):
        '''
        dir_path: dataset의 directory path입니다.
        batch_size: batch_size입니다.
        img_size: preprocess에 사용할 입력이미지의 크기입니다.
        output_size: ground_truth를 만들어주기 위한 크기입니다.
        is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
        augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
        '''
        self.dir_path = dir_path
        self.batch_size = batch_size
        self.is_train = is_train
        self.dir_path = dir_path
        self.augmentation = augmentation
        self.img_size = img_size
        self.output_size = output_size
        
        # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
        self.data = self.load_dataset()
        
    def load_dataset(self):
        # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
        # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
        input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
        label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
        input_images.sort()
        label_images.sort()
        assert len(input_images) == len(label_images)
        data = [ _ for _ in zip(input_images, label_images)]
        
        if self.is_train:
            return data[:-30]
        return data[-30:]
    
    def __len__(self):
        # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
        return math.ceil(len(self.data) / self.batch_size)
    
    def __getitem__(self, index):
        # 입력과 출력을 만듭니다.
        # 입력은 resize및 augmentation이 적용된 input image이고 
        # 출력은 semantic label입니다.
        batch_data = self.data[
            index*self.batch_size:
            (index + 1)*self.batch_size
        ]
        inputs = np.zeros([self.batch_size, *self.img_size])
        outputs = np.zeros([self.batch_size, *self.output_size])
        
        for i, data in enumerate(batch_data):
            input_img_path, output_path = data
            _input = imread(input_img_path)
            _output = imread(output_path)
            _output = (_output==7).astype(np.uint8)*1
            data = {
                "image": _input,
                "mask": _output,
            }
            augmented = self.augmentation(**data)
            inputs[i] = augmented["image"]/255
            outputs[i] = augmented["mask"]
            return inputs, outputs
        
    def on_epoch_end(self):
        # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
        self.indexes = np.arange(len(self.data))
        if self.is_train == True :
            np.random.shuffle(self.indexes)
            return self.indexes

# %%
dir_path = os.getenv('HOME')+'/aiffel/node_data/GD07/semantic_segmentation/data/training'

augmentation_train = build_augmentation()
augmentation_test = build_augmentation(is_train=False)
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %% [markdown]
# ## 모델 구축

# %%
def get_backbone(name, *args, **kwargs):
    return backbones[name](*args, **kwargs)

# %%
def get_layer_number(model, layer_name):
    for i, l in enumerate(model.layers):
        if l.name == layer_name:
            return i
    raise ValueError('No layer with name {} in  model {}.'.format(layer_name, model.name))

# %%
def freeze_model(model):
    for layer in model.layers:
        layer.trainable = False
    return

# %%
def to_tuple(x):
    if isinstance(x, tuple):
        if len(x) == 2:
            return x
    elif np.isscalar(x):
        return (x, x)

    raise ValueError('Value should be tuple of length 2 or int value, got "{}"'.format(x))

# %%
def handle_block_names(stage, cols):
    conv_name = 'decoder_stage{}-{}_conv'.format(stage, cols)
    bn_name = 'decoder_stage{}-{}_bn'.format(stage, cols)
    relu_name = 'decoder_stage{}-{}_relu'.format(stage, cols)
    up_name = 'decoder_stage{}-{}_upsample'.format(stage, cols)
    merge_name = 'merge_{}-{}'.format(stage, cols)
    return conv_name, bn_name, relu_name, up_name, merge_name

# %%
def ConvRelu(filters, kernel_size, use_batchnorm=False, conv_name='conv', bn_name='bn', relu_name='relu'):
    def layer(x):
        x = Conv2D(filters, kernel_size, padding="same", name=conv_name, use_bias=not(use_batchnorm))(x)
        if use_batchnorm:
            x = BatchNormalization(name=bn_name)(x)
        x = Activation('relu', name=relu_name)(x)
        return x
    return layer

# %%
def Transpose2D_block(filters, stage, cols, kernel_size=(3,3), upsample_rate=(2,2),
                      transpose_kernel_size=(4,4), use_batchnorm=False, skip=None):
    def layer(input_tensor):
        
        conv_name, bn_name, relu_name, up_name, merge_name = handle_block_names(stage, cols)
        
        x = Conv2DTranspose(filters, transpose_kernel_size, strides=upsample_rate,
                            padding='same', name=up_name, use_bias=not(use_batchnorm))(input_tensor)
        if use_batchnorm:
            x = BatchNormalization(name=bn_name+'1')(x)
        x = Activation('relu', name=relu_name+'1')(x)
        
        if (type(skip) != list and skip is not None) or (type(skip) == list and None not in skip):
            # print("\nskip = {}".format(skip))
            if type(skip) is list:
                merge_list = []
                merge_list.append(x)
                for l in skip:
                    merge_list.append(l)
                x = Concatenate(name=merge_name)(merge_list)
            else:
                x = Concatenate(name=merge_name)([x, skip])
                
            x = ConvRelu(filters, kernel_size, use_batchnorm=use_batchnorm,
                         conv_name=conv_name + '2', bn_name=bn_name + '2', relu_name=relu_name + '2')(x)
            
        return x
    return layer

# %%
def build_xnet(backbone, classes, skip_connection_layers,
               decoder_filters=(256,128,64,32,16),
               upsample_rates=(2,2,2,2,2),
               n_upsample_blocks=5,
               activation='sigmoid',
               use_batchnorm=True):
    
    input = backbone.input
    
    up_block = Transpose2D_block
        
    if len(skip_connection_layers) > n_upsample_blocks:
        downsampling_layers = skip_connection_layers[int(len(skip_connection_layers)/2):]
        skip_connection_layers = skip_connection_layers[:int(len(skip_connection_layers)/2)]
    else:
        downsampling_layers = skip_connection_layers
        
    skip_connection_idx = ([get_layer_number(backbone, l) if isinstance(l, str) else l
                               for l in skip_connection_layers])
    skip_layers_list = [backbone.layers[skip_connection_idx[i]].output for i in range(len(skip_connection_idx))]
    downsampling_idx = ([get_layer_number(backbone, l) if isinstance(l, str) else l
                               for l in downsampling_layers])
    downsampling_list = [backbone.layers[downsampling_idx[i]].output for i in range(len(downsampling_idx))]
    downterm = [None] * (n_upsample_blocks+1)
    
    for i in range(len(downsampling_idx)):
        if downsampling_list[0].name == backbone.output.name:
            downterm[n_upsample_blocks-i] = downsampling_list[i]
        else:
            downterm[n_upsample_blocks-i-1] = downsampling_list[i]
    downterm[-1] = backbone.output
    
    interm = [None] * (n_upsample_blocks+1) * (n_upsample_blocks+1)
    for i in range(len(skip_connection_idx)):
        interm[-i*(n_upsample_blocks+1)+(n_upsample_blocks+1)*(n_upsample_blocks-1)] = skip_layers_list[i]
    interm[(n_upsample_blocks+1)*n_upsample_blocks] = backbone.output
    
    for j in range(n_upsample_blocks):
        for i in range(n_upsample_blocks-j):
            upsample_rate = to_tuple(upsample_rates[i])
            
            if i == 0 and j < n_upsample_blocks-1 and len(skip_connection_layers) < n_upsample_blocks:
                interm[(n_upsample_blocks+1)*i+j+1] = None
            elif j == 0:
                if downterm[i+1] is not None:
                    interm[(n_upsample_blocks+1)*i+j+1] = up_block(decoder_filters[n_upsample_blocks-i-2], 
                                      i+1, j+1, upsample_rate=upsample_rate,
                                      skip=interm[(n_upsample_blocks+1)*i+j], 
                                      use_batchnorm=use_batchnorm)(downterm[i+1])
                else:
                    interm[(n_upsample_blocks+1)*i+j+1] = None
            else:
                interm[(n_upsample_blocks+1)*i+j+1] = up_block(decoder_filters[n_upsample_blocks-i-2], 
                                  i+1, j+1, upsample_rate=upsample_rate,
                                  skip=interm[(n_upsample_blocks+1)*i : (n_upsample_blocks+1)*i+j+1], 
                                  use_batchnorm=use_batchnorm)(interm[(n_upsample_blocks+1)*(i+1)+j])
    outlist = []
    for i in range(n_upsample_blocks):
        x = Conv2D(classes, (3,3), padding='same', name=f'final_conv{i+1}')(interm[i+1])
        x = Activation(activation, name=activation+(f'{i+1}'))(x)
        outlist.append(x)
        
    x = Concatenate(name='final_merge')(outlist)
    
    model = Model(input, x)
    
    return model

# %%
def Xnet(backbone_name='vgg16',
         input_shape=(None, None, 3),
         input_tensor=None,
         encoder_weights='imagenet',
         skip_connections='default',
         decoder_filters=(256,128,64,32,16),
         decoder_use_batchnorm=True,
         n_upsample_blocks=5,
         upsample_rates=(2,2,2,2,2),
         classes=1,
         activation='sigmoid'):
    
    backbone = get_backbone(backbone_name,
                            input_shape=input_shape,
                            input_tensor=input_tensor,
                            weights=encoder_weights,
                            include_top=False)
    
    if skip_connections == 'default':
        skip_connections = DEFAULT_SKIP_CONNECTIONS[backbone_name]
    
    model = build_xnet(backbone,
                       classes,
                       skip_connections,
                       decoder_filters=decoder_filters,
                       activation=activation,
                       n_upsample_blocks=n_upsample_blocks,
                       upsample_rates=upsample_rates,
                       use_batchnorm=decoder_use_batchnorm)
    
    return model

# %%
model = Xnet('vgg16', (224, 224, 3))

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# decoder_stage5-1_upsample (Conv (None, 14, 14, 16)   131072      block5_pool[0][0]
# __________________________________________________________________________________________________
# decoder_stage5-1_bn1 (BatchNorm (None, 14, 14, 16)   64          decoder_stage5-1_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage5-1_relu1 (Activat (None, 14, 14, 16)   0           decoder_stage5-1_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-1_upsample (Conv (None, 28, 28, 256)  2097152     block4_pool[0][0]
# __________________________________________________________________________________________________
# merge_5-1 (Concatenate)         (None, 14, 14, 528)  0           decoder_stage5-1_relu1[0][0]
#                                                                  block5_conv3[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-1_bn1 (BatchNorm (None, 28, 28, 256)  1024        decoder_stage4-1_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage5-1_conv2 (Conv2D) (None, 14, 14, 16)   76032       merge_5-1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-1_relu1 (Activat (None, 28, 28, 256)  0           decoder_stage4-1_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage5-1_bn2 (BatchNorm (None, 14, 14, 16)   64          decoder_stage5-1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-1_upsample (Conv (None, 56, 56, 128)  524288      block3_pool[0][0]
# __________________________________________________________________________________________________
# merge_4-1 (Concatenate)         (None, 28, 28, 768)  0           decoder_stage4-1_relu1[0][0]
#                                                                  block4_conv3[0][0]
# __________________________________________________________________________________________________
# decoder_stage5-1_relu2 (Activat (None, 14, 14, 16)   0           decoder_stage5-1_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-1_bn1 (BatchNorm (None, 56, 56, 128)  512         decoder_stage3-1_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-1_conv2 (Conv2D) (None, 28, 28, 256)  1769472     merge_4-1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-2_upsample (Conv (None, 28, 28, 256)  65536       decoder_stage5-1_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-1_relu1 (Activat (None, 56, 56, 128)  0           decoder_stage3-1_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-1_bn2 (BatchNorm (None, 28, 28, 256)  1024        decoder_stage4-1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-2_bn1 (BatchNorm (None, 28, 28, 256)  1024        decoder_stage4-2_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-1_upsample (Conv (None, 112, 112, 64) 131072      block2_pool[0][0]
# __________________________________________________________________________________________________
# merge_3-1 (Concatenate)         (None, 56, 56, 384)  0           decoder_stage3-1_relu1[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-1_relu2 (Activat (None, 28, 28, 256)  0           decoder_stage4-1_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-2_relu1 (Activat (None, 28, 28, 256)  0           decoder_stage4-2_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-1_bn1 (BatchNorm (None, 112, 112, 64) 256         decoder_stage2-1_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-1_conv2 (Conv2D) (None, 56, 56, 128)  442368      merge_3-1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-2_upsample (Conv (None, 56, 56, 128)  524288      decoder_stage4-1_relu2[0][0]
# __________________________________________________________________________________________________
# merge_4-2 (Concatenate)         (None, 28, 28, 1024) 0           decoder_stage4-2_relu1[0][0]
#                                                                  block4_conv3[0][0]
#                                                                  decoder_stage4-1_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-1_relu1 (Activat (None, 112, 112, 64) 0           decoder_stage2-1_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-1_bn2 (BatchNorm (None, 56, 56, 128)  512         decoder_stage3-1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-2_bn1 (BatchNorm (None, 56, 56, 128)  512         decoder_stage3-2_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-2_conv2 (Conv2D) (None, 28, 28, 256)  2359296     merge_4-2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-1_upsample (Conv (None, 224, 224, 32) 32768       block1_pool[0][0]
# __________________________________________________________________________________________________
# merge_2-1 (Concatenate)         (None, 112, 112, 192 0           decoder_stage2-1_relu1[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-1_relu2 (Activat (None, 56, 56, 128)  0           decoder_stage3-1_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-2_relu1 (Activat (None, 56, 56, 128)  0           decoder_stage3-2_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-2_bn2 (BatchNorm (None, 28, 28, 256)  1024        decoder_stage4-2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-1_bn1 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-1_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-1_conv2 (Conv2D) (None, 112, 112, 64) 110592      merge_2-1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-2_upsample (Conv (None, 112, 112, 64) 131072      decoder_stage3-1_relu2[0][0]
# __________________________________________________________________________________________________
# merge_3-2 (Concatenate)         (None, 56, 56, 512)  0           decoder_stage3-2_relu1[0][0]
#                                                                  block3_conv3[0][0]
#                                                                  decoder_stage3-1_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4-2_relu2 (Activat (None, 28, 28, 256)  0           decoder_stage4-2_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-1_relu1 (Activat (None, 224, 224, 32) 0           decoder_stage1-1_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-1_bn2 (BatchNorm (None, 112, 112, 64) 256         decoder_stage2-1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-2_bn1 (BatchNorm (None, 112, 112, 64) 256         decoder_stage2-2_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-2_conv2 (Conv2D) (None, 56, 56, 128)  589824      merge_3-2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-3_upsample (Conv (None, 56, 56, 128)  524288      decoder_stage4-2_relu2[0][0]
# __________________________________________________________________________________________________
# merge_1-1 (Concatenate)         (None, 224, 224, 96) 0           decoder_stage1-1_relu1[0][0]
#                                                                  block1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-1_relu2 (Activat (None, 112, 112, 64) 0           decoder_stage2-1_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-2_relu1 (Activat (None, 112, 112, 64) 0           decoder_stage2-2_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-2_bn2 (BatchNorm (None, 56, 56, 128)  512         decoder_stage3-2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-3_bn1 (BatchNorm (None, 56, 56, 128)  512         decoder_stage3-3_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-1_conv2 (Conv2D) (None, 224, 224, 32) 27648       merge_1-1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-2_upsample (Conv (None, 224, 224, 32) 32768       decoder_stage2-1_relu2[0][0]
# __________________________________________________________________________________________________
# merge_2-2 (Concatenate)         (None, 112, 112, 256 0           decoder_stage2-2_relu1[0][0]
#                                                                  block2_conv2[0][0]
#                                                                  decoder_stage2-1_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-2_relu2 (Activat (None, 56, 56, 128)  0           decoder_stage3-2_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-3_relu1 (Activat (None, 56, 56, 128)  0           decoder_stage3-3_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-1_bn2 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-2_bn1 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-2_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-2_conv2 (Conv2D) (None, 112, 112, 64) 147456      merge_2-2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-3_upsample (Conv (None, 112, 112, 64) 131072      decoder_stage3-2_relu2[0][0]
# __________________________________________________________________________________________________
# merge_3-3 (Concatenate)         (None, 56, 56, 640)  0           decoder_stage3-3_relu1[0][0]
#                                                                  block3_conv3[0][0]
#                                                                  decoder_stage3-1_relu2[0][0]
#                                                                  decoder_stage3-2_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-1_relu2 (Activat (None, 224, 224, 32) 0           decoder_stage1-1_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-2_relu1 (Activat (None, 224, 224, 32) 0           decoder_stage1-2_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-2_bn2 (BatchNorm (None, 112, 112, 64) 256         decoder_stage2-2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-3_bn1 (BatchNorm (None, 112, 112, 64) 256         decoder_stage2-3_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-3_conv2 (Conv2D) (None, 56, 56, 128)  737280      merge_3-3[0][0]
# __________________________________________________________________________________________________
# merge_1-2 (Concatenate)         (None, 224, 224, 128 0           decoder_stage1-2_relu1[0][0]
#                                                                  block1_conv2[0][0]
#                                                                  decoder_stage1-1_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-2_relu2 (Activat (None, 112, 112, 64) 0           decoder_stage2-2_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-3_relu1 (Activat (None, 112, 112, 64) 0           decoder_stage2-3_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-3_bn2 (BatchNorm (None, 56, 56, 128)  512         decoder_stage3-3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-2_conv2 (Conv2D) (None, 224, 224, 32) 36864       merge_1-2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-3_upsample (Conv (None, 224, 224, 32) 32768       decoder_stage2-2_relu2[0][0]
# __________________________________________________________________________________________________
# merge_2-3 (Concatenate)         (None, 112, 112, 320 0           decoder_stage2-3_relu1[0][0]
#                                                                  block2_conv2[0][0]
#                                                                  decoder_stage2-1_relu2[0][0]
#                                                                  decoder_stage2-2_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3-3_relu2 (Activat (None, 56, 56, 128)  0           decoder_stage3-3_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-2_bn2 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-3_bn1 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-3_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-3_conv2 (Conv2D) (None, 112, 112, 64) 184320      merge_2-3[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-4_upsample (Conv (None, 112, 112, 64) 131072      decoder_stage3-3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-2_relu2 (Activat (None, 224, 224, 32) 0           decoder_stage1-2_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-3_relu1 (Activat (None, 224, 224, 32) 0           decoder_stage1-3_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-3_bn2 (BatchNorm (None, 112, 112, 64) 256         decoder_stage2-3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-4_bn1 (BatchNorm (None, 112, 112, 64) 256         decoder_stage2-4_upsample[0][0]
# __________________________________________________________________________________________________
# merge_1-3 (Concatenate)         (None, 224, 224, 160 0           decoder_stage1-3_relu1[0][0]
#                                                                  block1_conv2[0][0]
#                                                                  decoder_stage1-1_relu2[0][0]
#                                                                  decoder_stage1-2_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-3_relu2 (Activat (None, 112, 112, 64) 0           decoder_stage2-3_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-4_relu1 (Activat (None, 112, 112, 64) 0           decoder_stage2-4_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-3_conv2 (Conv2D) (None, 224, 224, 32) 46080       merge_1-3[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-4_upsample (Conv (None, 224, 224, 32) 32768       decoder_stage2-3_relu2[0][0]
# __________________________________________________________________________________________________
# merge_2-4 (Concatenate)         (None, 112, 112, 384 0           decoder_stage2-4_relu1[0][0]
#                                                                  block2_conv2[0][0]
#                                                                  decoder_stage2-1_relu2[0][0]
#                                                                  decoder_stage2-2_relu2[0][0]
#                                                                  decoder_stage2-3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-3_bn2 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-4_bn1 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-4_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-4_conv2 (Conv2D) (None, 112, 112, 64) 221184      merge_2-4[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-3_relu2 (Activat (None, 224, 224, 32) 0           decoder_stage1-3_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-4_relu1 (Activat (None, 224, 224, 32) 0           decoder_stage1-4_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-4_bn2 (BatchNorm (None, 112, 112, 64) 256         decoder_stage2-4_conv2[0][0]
# __________________________________________________________________________________________________
# merge_1-4 (Concatenate)         (None, 224, 224, 192 0           decoder_stage1-4_relu1[0][0]
#                                                                  block1_conv2[0][0]
#                                                                  decoder_stage1-1_relu2[0][0]
#                                                                  decoder_stage1-2_relu2[0][0]
#                                                                  decoder_stage1-3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2-4_relu2 (Activat (None, 112, 112, 64) 0           decoder_stage2-4_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-4_conv2 (Conv2D) (None, 224, 224, 32) 55296       merge_1-4[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-5_upsample (Conv (None, 224, 224, 32) 32768       decoder_stage2-4_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-4_bn2 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-4_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-5_bn1 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-5_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-4_relu2 (Activat (None, 224, 224, 32) 0           decoder_stage1-4_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-5_relu1 (Activat (None, 224, 224, 32) 0           decoder_stage1-5_bn1[0][0]
# __________________________________________________________________________________________________
# merge_1-5 (Concatenate)         (None, 224, 224, 224 0           decoder_stage1-5_relu1[0][0]
#                                                                  block1_conv2[0][0]
#                                                                  decoder_stage1-1_relu2[0][0]
#                                                                  decoder_stage1-2_relu2[0][0]
#                                                                  decoder_stage1-3_relu2[0][0]
#                                                                  decoder_stage1-4_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-5_conv2 (Conv2D) (None, 224, 224, 32) 64512       merge_1-5[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-5_bn2 (BatchNorm (None, 224, 224, 32) 128         decoder_stage1-5_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1-5_relu2 (Activat (None, 224, 224, 32) 0           decoder_stage1-5_bn2[0][0]
# __________________________________________________________________________________________________
# final_conv1 (Conv2D)            (None, 224, 224, 1)  289         decoder_stage1-1_relu2[0][0]
# __________________________________________________________________________________________________
# final_conv2 (Conv2D)            (None, 224, 224, 1)  289         decoder_stage1-2_relu2[0][0]
# __________________________________________________________________________________________________
# final_conv3 (Conv2D)            (None, 224, 224, 1)  289         decoder_stage1-3_relu2[0][0]
# __________________________________________________________________________________________________
# final_conv4 (Conv2D)            (None, 224, 224, 1)  289         decoder_stage1-4_relu2[0][0]
# __________________________________________________________________________________________________
# final_conv5 (Conv2D)            (None, 224, 224, 1)  289         decoder_stage1-5_relu2[0][0]
# __________________________________________________________________________________________________
# sigmoid1 (Activation)           (None, 224, 224, 1)  0           final_conv1[0][0]
# __________________________________________________________________________________________________
# sigmoid2 (Activation)           (None, 224, 224, 1)  0           final_conv2[0][0]
# __________________________________________________________________________________________________
# sigmoid3 (Activation)           (None, 224, 224, 1)  0           final_conv3[0][0]
# __________________________________________________________________________________________________
# sigmoid4 (Activation)           (None, 224, 224, 1)  0           final_conv4[0][0]
# __________________________________________________________________________________________________
# sigmoid5 (Activation)           (None, 224, 224, 1)  0           final_conv5[0][0]
# __________________________________________________________________________________________________
# final_merge (Concatenate)       (None, 224, 224, 5)  0           sigmoid1[0][0]
#                                                                  sigmoid2[0][0]
#                                                                  sigmoid3[0][0]
#                                                                  sigmoid4[0][0]
#                                                                  sigmoid5[0][0]
# ==================================================================================================
# Total params: 26,149,733
# Trainable params: 26,144,421
# Non-trainable params: 5,312
# __________________________________________________________________________________________________

# %%
def dice_coef(y_true, y_pred):
    smooth = 1.0
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

# %%
def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice = dice_coef(y_true, y_pred)
    return 0.5 * bce + (1 - dice)

# %%
def custom_loss(y_true, y_pred):
    # y_pred shape: (batch_size, height, width, num_classes)
    num_classes = tf.keras.backend.int_shape(y_pred)[-1]  # Get the number of classes (e.g., 5)
    
    if len(y_true.shape) == 3:  # 채널 차원이 없다면
        y_true = tf.expand_dims(y_true, axis=-1)
    
    # Split y_pred along the channel axis
    y_pred_split = tf.split(y_pred, num_classes, axis=-1)
    
    # Compute loss for each class
    losses = []
    for pred in y_pred_split:
        loss = bce_dice_loss(y_true, pred)  # y_true is the same for all channels
        losses.append(loss)
    
    # Average the losses
    final_loss = tf.reduce_mean(losses)
    return final_loss

# %%
model_path = os.getenv('HOME')+'/aiffel/model_weight/GD07/vgg16_unet++.h5'

model.compile(optimizer = Adam(1e-4), loss = custom_loss)

history = model.fit(
     train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model.save(model_path)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 40s 1s/step - loss: 1.2730 - val_loss: 1.4665
# Epoch 2/100
# 11/11 [==============================] - 12s 1s/step - loss: 1.1759 - val_loss: 1.3263
# Epoch 3/100
# 11/11 [==============================] - 13s 1s/step - loss: 1.1000 - val_loss: 1.1729
# Epoch 4/100
# 11/11 [==============================] - 13s 1s/step - loss: 1.0588 - val_loss: 1.0376
# Epoch 5/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.9781 - val_loss: 0.9297
# Epoch 6/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.9507 - val_loss: 0.8936
# Epoch 7/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.9333 - val_loss: 0.8676
# Epoch 8/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.9343 - val_loss: 0.6917
# Epoch 9/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.8830 - val_loss: 0.6965
# Epoch 10/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.9123 - val_loss: 0.6788
# Epoch 11/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.7801 - val_loss: 0.5807
# Epoch 12/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.8429 - val_loss: 0.5889
# Epoch 13/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.7770 - val_loss: 0.5707
# Epoch 14/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.7916 - val_loss: 0.6158
# Epoch 15/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.6811 - val_loss: 0.5922
# Epoch 16/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.6269 - val_loss: 0.4765
# Epoch 17/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.6512 - val_loss: 0.4364
# Epoch 18/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.6417 - val_loss: 0.4580
# Epoch 19/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.5561 - val_loss: 0.4011
# Epoch 20/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.5172 - val_loss: 0.4442
# Epoch 21/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4987 - val_loss: 0.3890
# Epoch 22/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.5662 - val_loss: 0.3776
# Epoch 23/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.6199 - val_loss: 0.5055
# Epoch 24/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.6345 - val_loss: 0.5071
# Epoch 25/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3608 - val_loss: 0.3978
# Epoch 26/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4368 - val_loss: 0.4009
# Epoch 27/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4202 - val_loss: 0.8645
# Epoch 28/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4939 - val_loss: 0.7644
# Epoch 29/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.5501 - val_loss: 0.3865
# Epoch 30/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4345 - val_loss: 0.3807
# Epoch 31/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4986 - val_loss: 0.2947
# Epoch 32/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3413 - val_loss: 0.3098
# Epoch 33/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2632 - val_loss: 0.3022
# Epoch 34/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2676 - val_loss: 0.2952
# Epoch 35/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2712 - val_loss: 0.4202
# Epoch 36/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2669 - val_loss: 0.3172
# Epoch 37/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2919 - val_loss: 1.0471
# Epoch 38/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3762 - val_loss: 0.6686
# Epoch 39/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2484 - val_loss: 0.3362
# Epoch 40/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3669 - val_loss: 0.2199
# Epoch 41/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3332 - val_loss: 1.8510
# Epoch 42/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2587 - val_loss: 1.4286
# Epoch 43/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4446 - val_loss: 0.8378
# Epoch 44/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3412 - val_loss: 0.2728
# Epoch 45/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4203 - val_loss: 0.2714
# Epoch 46/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2685 - val_loss: 0.2826
# Epoch 47/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1824 - val_loss: 0.2813
# Epoch 48/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2575 - val_loss: 0.3294
# Epoch 49/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4002 - val_loss: 0.2971
# Epoch 50/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3372 - val_loss: 0.3286
# Epoch 51/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1752 - val_loss: 0.3823
# Epoch 52/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3319 - val_loss: 0.6031
# Epoch 53/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2781 - val_loss: 0.3732
# Epoch 54/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4172 - val_loss: 0.3199
# Epoch 55/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3899 - val_loss: 0.5989
# Epoch 56/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2087 - val_loss: 0.2536
# Epoch 57/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1592 - val_loss: 0.2581
# Epoch 58/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2281 - val_loss: 0.3073
# Epoch 59/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1978 - val_loss: 0.2378
# Epoch 60/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3419 - val_loss: 0.3872
# Epoch 61/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2088 - val_loss: 0.2401
# Epoch 62/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1249 - val_loss: 0.2091
# Epoch 63/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3258 - val_loss: 0.2254
# Epoch 64/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1269 - val_loss: 0.2160
# Epoch 65/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4179 - val_loss: 0.3198
# Epoch 66/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2443 - val_loss: 0.2136
# Epoch 67/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2427 - val_loss: 0.2253
# Epoch 68/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1529 - val_loss: 0.2274
# Epoch 69/100
# 11/11 [==============================] - 12s 1s/step - loss: 0.1853 - val_loss: 0.4684
# Epoch 70/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2734 - val_loss: 0.2528
# Epoch 71/100
# 11/11 [==============================] - 12s 1s/step - loss: 0.2332 - val_loss: 0.2529
# Epoch 72/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3436 - val_loss: 0.2376
# Epoch 73/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2344 - val_loss: 0.3048
# Epoch 74/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2033 - val_loss: 0.2008
# Epoch 75/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.0855 - val_loss: 0.1953
# Epoch 76/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3327 - val_loss: 0.2151
# Epoch 77/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4319 - val_loss: 0.2545
# Epoch 78/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2874 - val_loss: 0.2061
# Epoch 79/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2858 - val_loss: 0.2303
# Epoch 80/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1922 - val_loss: 0.2539
# Epoch 81/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2282 - val_loss: 0.2085
# Epoch 82/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2253 - val_loss: 0.2259
# Epoch 83/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2917 - val_loss: 0.2115
# Epoch 84/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2925 - val_loss: 0.2248
# Epoch 85/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3527 - val_loss: 0.2163
# Epoch 86/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1983 - val_loss: 0.2222
# Epoch 87/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1077 - val_loss: 0.2022
# Epoch 88/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3098 - val_loss: 0.2154
# Epoch 89/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2184 - val_loss: 0.2570
# Epoch 90/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1627 - val_loss: 0.2104
# Epoch 91/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.3559 - val_loss: 0.2002
# Epoch 92/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1880 - val_loss: 0.2447
# Epoch 93/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2858 - val_loss: 0.1837
# Epoch 94/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2121 - val_loss: 1.0485
# Epoch 95/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2297 - val_loss: 2.8781
# Epoch 96/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.4481 - val_loss: 0.2539
# Epoch 97/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1851 - val_loss: 0.1927
# Epoch 98/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.2720 - val_loss: 0.2028
# Epoch 99/100
# 11/11 [==============================] - 13s 1s/step - loss: 0.1633 - val_loss: 0.1766
# Epoch 100/100
# 11/11 [==============================] - 12s 1s/step - loss: 0.1131 - val_loss: 0.1811

# %%
plt.figure(figsize=(14, 8))

plt.plot(history.history['loss'], 'r')
plt.plot(history.history['val_loss'], 'y')
plt.title('Model train loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='best')
plt.show()

# %% [markdown]
# ## 모델 시각화

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction).sum()
    union = np.logical_or(target, prediction).sum()
    iou_score = float(intersection) / float(union) if union != 0 else 0.0
    print('IoU : %f' % iou_score )
    return iou_score

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output_split = tf.split(output, 5, axis=-1)
    output = output_split[-1]
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()   # 도로로 판단한 영역을 시각화!
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %%
i = 3
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x79B4E932D490>
# IoU : 0.629851
# 0.6298505024099338

# %%
i = 9
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x79B4E0769850>
# IoU : 0.757694
# 0.7576938739891791
