# %%
# TensorFlow and tf.keras
import json
import random
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 데이터 import

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

# %%
tfds.show_examples(ds_train, ds_info)

# %% [markdown]
# # 주요 함수

# %%
def normalize_and_resize_img(image, label):
    image = tf.image.resize(image, [224, 224])
    return tf.cast(image, tf.float32) / 255., label

# %%
def onehot(image, label):
    label = tf.one_hot(label, num_classes)
    return image, label

# %%
def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.clip_by_value(image, 0, 1)
    return image, label

# %%
def augment2(image,label):
    choice = [random.random() for value in range(8)]

    augmentations = [
        lambda img: tf.image.random_brightness(img, max_delta=0.2),
        lambda img: tf.image.random_contrast(img, lower=0.8, upper=1.2),
        lambda img: tf.image.central_crop(img, central_fraction=random.uniform(0.7, 1.0)),
        lambda img: tf.image.random_flip_left_right(img),
        lambda img: tf.image.random_flip_up_down(img),
        lambda img: tf.image.random_hue(img, max_delta=0.2),
        lambda img: tf.image.random_jpeg_quality(img, min_jpeg_quality=70, max_jpeg_quality=100),
        lambda img: tf.image.random_saturation(img, lower=0.8, upper=1.2),
    ]
    
    for apply, augment in zip(choice, augmentations):
        if apply:
            image = augment(image)
            
    image = tf.clip_by_value(image, 0, 1)
    
    return image, label

# %%
def get_clip_box(image_a, image_b):
    # image.shape = (height, width, channel)
    image_size_x = image_a.shape[1]
    image_size_y = image_a.shape[0]
    
    # get center of box
    x = tf.cast(tf.random.uniform([], 0, image_size_x), tf.int32)
    y = tf.cast(tf.random.uniform([], 0, image_size_y), tf.int32)

    # get width, height of box
    width = tf.cast(image_size_x*tf.math.sqrt(1-tf.random.uniform([], 0, 1)), tf.int32)
    height = tf.cast(image_size_y*tf.math.sqrt(1-tf.random.uniform([], 0, 1)), tf.int32)
    
    # clip box in image and get minmax bbox
    x_min = tf.math.maximum(0, x-width//2)
    y_min = tf.math.maximum(0, y-height//2)
    x_max = tf.math.minimum(image_size_x, x+width//2)
    y_max = tf.math.minimum(image_size_y, y+height//2)
    
    return x_min, y_min, x_max, y_max

# %%
# mix two images
def mix_2_images(image_a, image_b, x_min, y_min, x_max, y_max):
    image_size_x = image_a.shape[1]
    image_size_y = image_a.shape[0] 
    middle_left = image_a[y_min:y_max, 0:x_min, :] # image_b의 왼쪽 바깥 영역
    middle_center = image_b[y_min:y_max, x_min:x_max, :]  # image_b의 안쪽 영역
    middle_right = image_a[y_min:y_max, x_max:image_size_x, :] # image_b의 오른쪽 바깥 영역
    middle = tf.concat([middle_left,middle_center,middle_right], axis=1)
    top = image_a[0:y_min, :, :]
    bottom = image_a[y_max:image_size_y, :, :]
    mixed_img = tf.concat([top, middle, bottom],axis=0)
    
    return mixed_img

# %%
# mix two labels
def mix_2_labels(label_a, label_b, mixed_img, x_min, y_min, x_max, y_max, num_classes=120):
    image_size_x = mixed_img.shape[1]
    image_size_y = mixed_img.shape[0] 
    mixed_area = (x_max-x_min)*(y_max-y_min)
    total_area = image_size_x*image_size_y
    ratio = tf.cast(mixed_area/total_area, tf.float32)

    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_label = (1-ratio)*label_a + ratio*label_b
    return mixed_label

# %%
def cutmix(image, label, prob=1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([],0, batch_size),tf.int32)
        image_b = image[j]
        label_b = label[j]
        x_min, y_min, x_max, y_max = get_clip_box(image_a, image_b)
        mixed_imgs.append(mix_2_images(image_a, image_b, x_min, y_min, x_max, y_max))
        mixed_labels.append(mix_2_labels(label_a, label_b, image_a, x_min, y_min, x_max, y_max))
        
    mixed_imgs = tf.reshape(tf.stack(mixed_imgs), (batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels), (batch_size, num_classes))
    return mixed_imgs, mixed_labels

# %%
# function for mixup
def mixup_2_images(image_a, image_b, label_a, label_b):
    ratio = tf.random.uniform([], 0, 1)
    
    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_image= (1-ratio)*image_a + ratio*image_b
    mixed_label = (1-ratio)*label_a + ratio*label_b
    
    return mixed_image, mixed_label

# %%
def mixup(image, label, prob=1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([],0,batch_size), tf.int32)
        image_b = image[j]
        label_b = label[j]
        mixed_img, mixed_label = mixup_2_images(image_a, image_b, label_a, label_b)
        mixed_imgs.append(mixed_img)
        mixed_labels.append(mixed_label)

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs), (batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels), (batch_size, num_classes))
    return mixed_imgs, mixed_labels

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16, with_aug=False, with_cutmix=False, with_mixup=False):
    ds = ds.map(
        normalize_and_resize_img,
        num_parallel_calls=2
    )
    ds = ds.map(
        onehot,
        num_parallel_calls=2
    )
    if not is_test and with_aug:
        ds_aug = ds.map(
            augment2
        )
        ds = ds.concatenate(ds_aug)
    ds = ds.batch(batch_size)
    if not is_test and with_mixup:
        ds_mixup = ds.map(
            mixup,
            num_parallel_calls=2
        )
        ds = ds.concatenate(ds_mixup)
    if not is_test and with_cutmix:
        ds_cutmix = ds.map(
            cutmix,
            num_parallel_calls=2
        )
        ds = ds.concatenate(ds_cutmix)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
def apply_normalize_on_dataset_nol(ds, is_test=False, batch_size=16, with_aug=False, with_cutmix=False, with_mixup=False):
    ds = ds.map(
        normalize_and_resize_img,
        num_parallel_calls=2
    )
    ds = ds.map(
        onehot,
        num_parallel_calls=2
    )
    if not is_test and with_aug:
        ds = ds.map(
            augment2
        )
    ds = ds.batch(batch_size)
    if not is_test and with_mixup:
        ds = ds.map(
            mixup,
            num_parallel_calls=2
        )
    if not is_test and with_cutmix:
        ds = ds.map(
            cutmix,
            num_parallel_calls=2
        )
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
def history_conv(history):
    
    return_history = {'loss' : list(history['loss'].values()),
                      'accuracy' : list(history['accuracy'].values()),
                      'val_loss' : list(history['val_loss'].values()),
                      'val_accuracy' : list(history['val_accuracy'].values())}
    
    return return_history

# %% [markdown]
# ## 모델 구축

# %%
num_classes = ds_info.features["label"].num_classes

# %% [markdown]
# ### Classic resnet

# %%
resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ### Aug resnet

# %%
aug_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ### Cutmix resnet

# %%
cutmix_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ### Mixup resnet

# %%
mixup_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(224,224,3),
        pooling='avg',
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ## 데이터 준비

# %%
BATCH_SIZE = 16

# %% [markdown]
# ### 합쳐진 데이터

# %%
ds_train_classic = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)

# %%
ds_train_augmentation = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE, with_aug=True)

# %%
ds_train_cutmix = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE, with_cutmix=True)

# %%
ds_train_mixup = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE, with_mixup=True)

# %%
ds_test_all = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE, is_test=True)

# %% [markdown]
# ### 합치지 않은 데이터

# %%
ds_train_nolaug = apply_normalize_on_dataset_nol(ds_train, batch_size=BATCH_SIZE, with_aug=True)

# %%
ds_train_nolcutmix = apply_normalize_on_dataset_nol(ds_train, batch_size=BATCH_SIZE, with_cutmix=True)

# %%
ds_train_nolmixup = apply_normalize_on_dataset_nol(ds_train, batch_size=BATCH_SIZE, with_mixup=True)

# %% [markdown]
# # 실험 Log

# %% [markdown]
# ## 과대적합 찾기

# %% [markdown]
# ### epoch = 5, learning rate = 0.01

# %%
EPOCH = 5

# %%
resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    metrics=['accuracy'],
)

history_resnet50 = resnet50.fit(
    ds_train_classic,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test_all,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# 750/750 [==============================] - 164s 203ms/step - loss: 2.2152 - accuracy: 0.4451 - val_loss: 3.3659 - val_accuracy: 0.2176
# Epoch 2/5
# 750/750 [==============================] - 151s 201ms/step - loss: 0.7762 - accuracy: 0.7809 - val_loss: 1.0472 - val_accuracy: 0.6932
# Epoch 3/5
# 750/750 [==============================] - 151s 201ms/step - loss: 0.3018 - accuracy: 0.9268 - val_loss: 1.0386 - val_accuracy: 0.7021
# Epoch 4/5
# 750/750 [==============================] - 151s 201ms/step - loss: 0.0930 - accuracy: 0.9872 - val_loss: 0.8997 - val_accuracy: 0.7404
# Epoch 5/5
# 750/750 [==============================] - 151s 201ms/step - loss: 0.0348 - accuracy: 0.9975 - val_loss: 0.9306 - val_accuracy: 0.7399

# %%
with open('history/history_resnet50.json', 'w') as f:
    pd.DataFrame(history_resnet50.history).to_json(f)

# %%
del resnet50

# %%
aug_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    metrics=['accuracy'],
)

history_resnet50_aug = aug_resnet50.fit(
    ds_train_augmentation,
    steps_per_epoch=int(2*ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test_all,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 265s 172ms/step - loss: 2.1315 - accuracy: 0.4455 - val_loss: 1.5198 - val_accuracy: 0.5667
# Epoch 2/5
# 1500/1500 [==============================] - 252s 168ms/step - loss: 1.0276 - accuracy: 0.7078 - val_loss: 1.5587 - val_accuracy: 0.5681
# Epoch 3/5
# 1500/1500 [==============================] - 267s 178ms/step - loss: 0.6295 - accuracy: 0.8227 - val_loss: 1.1708 - val_accuracy: 0.6630
# Epoch 4/5
# 1500/1500 [==============================] - 252s 168ms/step - loss: 0.4110 - accuracy: 0.8894 - val_loss: 1.2066 - val_accuracy: 0.6688
# Epoch 5/5
# 1500/1500 [==============================] - 252s 168ms/step - loss: 0.2891 - accuracy: 0.9249 - val_loss: 1.2568 - val_accuracy: 0.6607

# %%
with open('history/history_resnet50_aug.json', 'w') as f:
    pd.DataFrame(history_resnet50_aug.history).to_json(f)

# %%
del aug_resnet50

# %%
cutmix_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    metrics=['accuracy'],
)

history_resnet50_cutmix = cutmix_resnet50.fit(
    ds_train_cutmix,
    steps_per_epoch=int(2*ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test_all,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 286s 186ms/step - loss: 2.4006 - accuracy: 0.4887 - val_loss: 1.1307 - val_accuracy: 0.6734
# Epoch 2/5
# 1500/1500 [==============================] - 278s 185ms/step - loss: 1.3806 - accuracy: 0.7762 - val_loss: 1.0209 - val_accuracy: 0.7080
# Epoch 3/5
# 1500/1500 [==============================] - 279s 186ms/step - loss: 1.1260 - accuracy: 0.8519 - val_loss: 1.1445 - val_accuracy: 0.6811
# Epoch 4/5
# 1500/1500 [==============================] - 278s 186ms/step - loss: 1.0435 - accuracy: 0.8704 - val_loss: 1.1361 - val_accuracy: 0.6885
# Epoch 5/5
# 1500/1500 [==============================] - 278s 185ms/step - loss: 1.0053 - accuracy: 0.8762 - val_loss: 1.1341 - val_accuracy: 0.6973

# %%
with open('history/history_resnet50_cutmix.json', 'w') as f:
    pd.DataFrame(history_resnet50_cutmix.history).to_json(f)

# %%
del cutmix_resnet50

# %%
mixup_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    metrics=['accuracy'],
)

history_resnet50_mixup = mixup_resnet50.fit(
    ds_train_cutmix,
    steps_per_epoch=int(2*ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test_all,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 285s 186ms/step - loss: 2.4158 - accuracy: 0.4851 - val_loss: 1.2864 - val_accuracy: 0.6356
# Epoch 2/5
# 1500/1500 [==============================] - 278s 185ms/step - loss: 1.3842 - accuracy: 0.7771 - val_loss: 1.0427 - val_accuracy: 0.7004
# Epoch 3/5
# 1500/1500 [==============================] - 278s 185ms/step - loss: 1.1326 - accuracy: 0.8501 - val_loss: 1.0717 - val_accuracy: 0.7003
# Epoch 4/5
# 1500/1500 [==============================] - 278s 185ms/step - loss: 1.0378 - accuracy: 0.8691 - val_loss: 1.0179 - val_accuracy: 0.7239
# Epoch 5/5
# 1500/1500 [==============================] - 278s 185ms/step - loss: 0.9978 - accuracy: 0.8802 - val_loss: 1.0414 - val_accuracy: 0.7164

# %%
with open('history/history_resnet50_mixup.json', 'w') as f:
    pd.DataFrame(history_resnet50_mixup.history).to_json(f)

# %%
del mixup_resnet50

# %%
with open('history/history_resnet50.json', 'r') as f:
    history_resnet50 = json.load(f)

# %%
with open('history/history_resnet50_aug.json', 'r') as f:
    history_resnet50_aug = json.load(f)

# %%
with open('history/history_resnet50_cutmix.json', 'r') as f:
    history_resnet50_cutmix = json.load(f)

# %%
with open('history/history_resnet50_mixup.json', 'r') as f:
    history_resnet50_mixup = json.load(f)

# %%
history_resnet50 = history_conv(history_resnet50)
history_resnet50_aug = history_conv(history_resnet50_aug)
history_resnet50_cutmix = history_conv(history_resnet50_cutmix)
history_resnet50_mixup = history_conv(history_resnet50_mixup)

# %%
plt.figure(figsize=(14, 5))

plt.subplot(121)
plt.plot(history_resnet50['loss'], 'r')
plt.plot(history_resnet50['val_loss'], 'b')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(122)
plt.plot(history_resnet50['accuracy'], 'r')
plt.plot(history_resnet50['val_accuracy'], 'b')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(14, 5))

plt.subplot(121)
plt.plot(history_resnet50_aug['loss'], 'r')
plt.plot(history_resnet50_aug['val_loss'], 'b')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(122)
plt.plot(history_resnet50_aug['accuracy'], 'r')
plt.plot(history_resnet50_aug['val_accuracy'], 'b')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(14, 5))

plt.subplot(121)
plt.plot(history_resnet50_cutmix['loss'], 'r')
plt.plot(history_resnet50_cutmix['val_loss'], 'b')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(122)
plt.plot(history_resnet50_cutmix['accuracy'], 'r')
plt.plot(history_resnet50_cutmix['val_accuracy'], 'b')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(14, 5))

plt.subplot(121)
plt.plot(history_resnet50_mixup['loss'], 'r')
plt.plot(history_resnet50_mixup['val_loss'], 'b')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(122)
plt.plot(history_resnet50_mixup['accuracy'], 'r')
plt.plot(history_resnet50_mixup['val_accuracy'], 'b')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### epoch = 50, learning rate = 0.001

# %%
EPOCH = 50

# %%
checkpoint_basic = tf.keras.callbacks.ModelCheckpoint("history/resnet50.keras", monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

# %%
checkpoint_aug = tf.keras.callbacks.ModelCheckpoint("history/resnet50_aug.keras", monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

# %%
checkpoint_cutmix = tf.keras.callbacks.ModelCheckpoint("history/resnet50_cutmix.keras", monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

# %%
checkpoint_mixup = tf.keras.callbacks.ModelCheckpoint("history/resnet50_mixup.keras", monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

# %%
resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    metrics=['accuracy'],
)

history_resnet50_2 = resnet50.fit(
    ds_train_classic,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test_all,
    verbose=1,
    use_multiprocessing=True,
    callbacks=[checkpoint_basic]
)
# Out:
# Epoch 1/50
# 750/750 [==============================] - 167s 207ms/step - loss: 4.4564 - accuracy: 0.0780 - val_loss: 4.6899 - val_accuracy: 0.0436
#
# Epoch 00001: val_loss improved from inf to 4.68988, saving model to history/resnet50.keras
# Epoch 2/50
# 750/750 [==============================] - 155s 206ms/step - loss: 2.9342 - accuracy: 0.3706 - val_loss: 2.2356 - val_accuracy: 0.4750
#
# Epoch 00002: val_loss improved from 4.68988 to 2.23561, saving model to history/resnet50.keras
# Epoch 3/50
# 750/750 [==============================] - 155s 206ms/step - loss: 2.0091 - accuracy: 0.5592 - val_loss: 1.6501 - val_accuracy: 0.5792
#
# Epoch 00003: val_loss improved from 2.23561 to 1.65007, saving model to history/resnet50.keras
# Epoch 4/50
# 750/750 [==============================] - 155s 206ms/step - loss: 1.5025 - accuracy: 0.6565 - val_loss: 1.3656 - val_accuracy: 0.6348
#
# Epoch 00004: val_loss improved from 1.65007 to 1.36561, saving model to history/resnet50.keras
# Epoch 5/50
# 750/750 [==============================] - 154s 206ms/step - loss: 1.1488 - accuracy: 0.7473 - val_loss: 1.2152 - val_accuracy: 0.6644
#
# Epoch 00005: val_loss improved from 1.36561 to 1.21524, saving model to history/resnet50.keras
# Epoch 6/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.9112 - accuracy: 0.8052 - val_loss: 1.1514 - val_accuracy: 0.6706
#
# Epoch 00006: val_loss improved from 1.21524 to 1.15139, saving model to history/resnet50.keras
# Epoch 7/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.7334 - accuracy: 0.8596 - val_loss: 1.0772 - val_accuracy: 0.6885
#
# Epoch 00007: val_loss improved from 1.15139 to 1.07716, saving model to history/resnet50.keras
# Epoch 8/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.5806 - accuracy: 0.9025 - val_loss: 1.0536 - val_accuracy: 0.6909
#
# Epoch 00008: val_loss improved from 1.07716 to 1.05359, saving model to history/resnet50.keras
# Epoch 9/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.4657 - accuracy: 0.9302 - val_loss: 1.0217 - val_accuracy: 0.6975
#
# Epoch 00009: val_loss improved from 1.05359 to 1.02170, saving model to history/resnet50.keras
# Epoch 10/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.3744 - accuracy: 0.9563 - val_loss: 1.0090 - val_accuracy: 0.7039
#
# Epoch 00010: val_loss improved from 1.02170 to 1.00900, saving model to history/resnet50.keras
# Epoch 11/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.3118 - accuracy: 0.9678 - val_loss: 0.9976 - val_accuracy: 0.7027
#
# Epoch 00011: val_loss improved from 1.00900 to 0.99762, saving model to history/resnet50.keras
# Epoch 12/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.3082 - accuracy: 0.9637 - val_loss: 0.9921 - val_accuracy: 0.7053
#
# Epoch 00012: val_loss improved from 0.99762 to 0.99206, saving model to history/resnet50.keras
# Epoch 13/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.2148 - accuracy: 0.9862 - val_loss: 0.9922 - val_accuracy: 0.7060
#
# Epoch 00013: val_loss did not improve from 0.99206
# Epoch 14/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.1795 - accuracy: 0.9895 - val_loss: 0.9879 - val_accuracy: 0.7071
#
# Epoch 00014: val_loss improved from 0.99206 to 0.98791, saving model to history/resnet50.keras
# Epoch 15/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.1507 - accuracy: 0.9936 - val_loss: 0.9883 - val_accuracy: 0.7080
#
# Epoch 00015: val_loss did not improve from 0.98791
# Epoch 16/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.1314 - accuracy: 0.9958 - val_loss: 0.9878 - val_accuracy: 0.7101
#
# Epoch 00016: val_loss improved from 0.98791 to 0.98775, saving model to history/resnet50.keras
# Epoch 17/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.1113 - accuracy: 0.9966 - val_loss: 0.9916 - val_accuracy: 0.7094
#
# Epoch 00017: val_loss did not improve from 0.98775
# Epoch 18/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0979 - accuracy: 0.9977 - val_loss: 0.9912 - val_accuracy: 0.7123
#
# Epoch 00018: val_loss did not improve from 0.98775
# Epoch 19/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0869 - accuracy: 0.9980 - val_loss: 0.9988 - val_accuracy: 0.7112
#
# Epoch 00019: val_loss did not improve from 0.98775
# Epoch 20/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0771 - accuracy: 0.9985 - val_loss: 1.0007 - val_accuracy: 0.7084
#
# Epoch 00020: val_loss did not improve from 0.98775
# Epoch 21/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0691 - accuracy: 0.9988 - val_loss: 1.0025 - val_accuracy: 0.7092
#
# Epoch 00021: val_loss did not improve from 0.98775
# Epoch 22/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0641 - accuracy: 0.9987 - val_loss: 1.0078 - val_accuracy: 0.7090
#
# Epoch 00022: val_loss did not improve from 0.98775
# Epoch 23/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0583 - accuracy: 0.9990 - val_loss: 1.0109 - val_accuracy: 0.7108
#
# Epoch 00023: val_loss did not improve from 0.98775
# Epoch 24/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0519 - accuracy: 0.9995 - val_loss: 1.0162 - val_accuracy: 0.7092
#
# Epoch 00024: val_loss did not improve from 0.98775
# Epoch 25/50
# 750/750 [==============================] - 169s 226ms/step - loss: 0.0493 - accuracy: 0.9992 - val_loss: 1.0171 - val_accuracy: 0.7108
#
# Epoch 00025: val_loss did not improve from 0.98775
# Epoch 26/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0448 - accuracy: 0.9997 - val_loss: 1.0225 - val_accuracy: 0.7095
#
# Epoch 00026: val_loss did not improve from 0.98775
# Epoch 27/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0419 - accuracy: 0.9998 - val_loss: 1.0267 - val_accuracy: 0.7091
#
# Epoch 00027: val_loss did not improve from 0.98775
# Epoch 28/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 1.0298 - val_accuracy: 0.7100
#
# Epoch 00028: val_loss did not improve from 0.98775
# Epoch 29/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0365 - accuracy: 0.9996 - val_loss: 1.0338 - val_accuracy: 0.7080
#
# Epoch 00029: val_loss did not improve from 0.98775
# Epoch 30/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0337 - accuracy: 0.9999 - val_loss: 1.0360 - val_accuracy: 0.7084
#
# Epoch 00030: val_loss did not improve from 0.98775
# Epoch 31/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0304 - accuracy: 0.9998 - val_loss: 1.0385 - val_accuracy: 0.7100
#
# Epoch 00031: val_loss did not improve from 0.98775
# Epoch 32/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0299 - accuracy: 0.9998 - val_loss: 1.0422 - val_accuracy: 0.7090
#
# Epoch 00032: val_loss did not improve from 0.98775
# Epoch 33/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0293 - accuracy: 0.9996 - val_loss: 1.0511 - val_accuracy: 0.7066
#
# Epoch 00033: val_loss did not improve from 0.98775
# Epoch 34/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0303 - accuracy: 0.9998 - val_loss: 1.0477 - val_accuracy: 0.7091
#
# Epoch 00034: val_loss did not improve from 0.98775
# Epoch 35/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0260 - accuracy: 0.9998 - val_loss: 1.0507 - val_accuracy: 0.7084
#
# Epoch 00035: val_loss did not improve from 0.98775
# Epoch 36/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0247 - accuracy: 0.9998 - val_loss: 1.0541 - val_accuracy: 0.7097
#
# Epoch 00036: val_loss did not improve from 0.98775
# Epoch 37/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0228 - accuracy: 0.9998 - val_loss: 1.0551 - val_accuracy: 0.7091
#
# Epoch 00037: val_loss did not improve from 0.98775
# Epoch 38/50
# 750/750 [==============================] - 169s 226ms/step - loss: 0.0215 - accuracy: 0.9998 - val_loss: 1.0589 - val_accuracy: 0.7073
#
# Epoch 00038: val_loss did not improve from 0.98775
# Epoch 39/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0215 - accuracy: 0.9998 - val_loss: 1.0625 - val_accuracy: 0.7111
#
# Epoch 00039: val_loss did not improve from 0.98775
# Epoch 40/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0201 - accuracy: 0.9998 - val_loss: 1.0715 - val_accuracy: 0.7066
#
# Epoch 00040: val_loss did not improve from 0.98775
# Epoch 41/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 1.0667 - val_accuracy: 0.7087
#
# Epoch 00041: val_loss did not improve from 0.98775
# Epoch 42/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0189 - accuracy: 0.9999 - val_loss: 1.0689 - val_accuracy: 0.7101
#
# Epoch 00042: val_loss did not improve from 0.98775
# Epoch 43/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0179 - accuracy: 0.9998 - val_loss: 1.0739 - val_accuracy: 0.7077
#
# Epoch 00043: val_loss did not improve from 0.98775
# Epoch 44/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0173 - accuracy: 0.9998 - val_loss: 1.0746 - val_accuracy: 0.7098
#
# Epoch 00044: val_loss did not improve from 0.98775
# Epoch 45/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0168 - accuracy: 0.9998 - val_loss: 1.0750 - val_accuracy: 0.7093
#
# Epoch 00045: val_loss did not improve from 0.98775
# Epoch 46/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0164 - accuracy: 0.9996 - val_loss: 1.0837 - val_accuracy: 0.7093
#
# Epoch 00046: val_loss did not improve from 0.98775
# Epoch 47/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 1.0809 - val_accuracy: 0.7079
#
# Epoch 00047: val_loss did not improve from 0.98775
# Epoch 48/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0147 - accuracy: 0.9998 - val_loss: 1.0846 - val_accuracy: 0.7074
#
# Epoch 00048: val_loss did not improve from 0.98775
# Epoch 49/50
# 750/750 [==============================] - 155s 206ms/step - loss: 0.0145 - accuracy: 0.9998 - val_loss: 1.0831 - val_accuracy: 0.7114
#
# Epoch 00049: val_loss did not improve from 0.98775
# Epoch 50/50
# 750/750 [==============================] - 154s 206ms/step - loss: 0.0144 - accuracy: 0.9998 - val_loss: 1.0880 - val_accuracy: 0.7083
#
# Epoch 00050: val_loss did not improve from 0.98775

# %%
with open('history/history_resnet50_2.json', 'w') as f:
    pd.DataFrame(history_resnet50_2.history).to_json(f)

# %%
del resnet50

# %%
aug_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    metrics=['accuracy'],
)

history_resnet50_aug_2 = aug_resnet50.fit(
    ds_train_augmentation,
    steps_per_epoch=int(2*ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test_all,
    verbose=1,
    use_multiprocessing=True,
    callbacks=[checkpoint_aug]
)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 273s 170ms/step - loss: 4.0545 - accuracy: 0.1326 - val_loss: 2.5907 - val_accuracy: 0.4095
#
# Epoch 00001: val_loss improved from 4.65443 to 2.59073, saving model to history/resnet50_aug.keras
# Epoch 2/50
# 1500/1500 [==============================] - 246s 164ms/step - loss: 2.4667 - accuracy: 0.4252 - val_loss: 1.6913 - val_accuracy: 0.5848
#
# Epoch 00002: val_loss improved from 2.59073 to 1.69131, saving model to history/resnet50_aug.keras
# Epoch 3/50
# 1500/1500 [==============================] - 247s 165ms/step - loss: 1.8233 - accuracy: 0.5508 - val_loss: 1.3847 - val_accuracy: 0.6458
#
# Epoch 00003: val_loss improved from 1.69131 to 1.38467, saving model to history/resnet50_aug.keras
# Epoch 4/50
# 1500/1500 [==============================] - 250s 167ms/step - loss: 1.4863 - accuracy: 0.6252 - val_loss: 1.2531 - val_accuracy: 0.6728
#
# Epoch 00004: val_loss improved from 1.38467 to 1.25307, saving model to history/resnet50_aug.keras
# Epoch 5/50
# 1500/1500 [==============================] - 260s 173ms/step - loss: 1.2499 - accuracy: 0.6827 - val_loss: 1.1564 - val_accuracy: 0.6881
#
# Epoch 00005: val_loss improved from 1.25307 to 1.15640, saving model to history/resnet50_aug.keras
# Epoch 6/50
# 1500/1500 [==============================] - 250s 167ms/step - loss: 1.0673 - accuracy: 0.7318 - val_loss: 1.1063 - val_accuracy: 0.6940
#
# Epoch 00006: val_loss improved from 1.15640 to 1.10633, saving model to history/resnet50_aug.keras
# Epoch 7/50
# 1500/1500 [==============================] - 245s 163ms/step - loss: 0.9338 - accuracy: 0.7690 - val_loss: 1.1209 - val_accuracy: 0.6943
#
# Epoch 00007: val_loss did not improve from 1.10633
# Epoch 8/50
# 1500/1500 [==============================] - 249s 166ms/step - loss: 0.8308 - accuracy: 0.7951 - val_loss: 1.0950 - val_accuracy: 0.6924
#
# Epoch 00008: val_loss improved from 1.10633 to 1.09501, saving model to history/resnet50_aug.keras
# Epoch 9/50
# 1500/1500 [==============================] - 244s 163ms/step - loss: 0.7257 - accuracy: 0.8250 - val_loss: 1.0388 - val_accuracy: 0.7104
#
# Epoch 00009: val_loss improved from 1.09501 to 1.03878, saving model to history/resnet50_aug.keras
# Epoch 10/50
# 1500/1500 [==============================] - 244s 163ms/step - loss: 0.6349 - accuracy: 0.8466 - val_loss: 1.0502 - val_accuracy: 0.7013
#
# Epoch 00010: val_loss did not improve from 1.03878
# Epoch 11/50
# 1500/1500 [==============================] - 259s 172ms/step - loss: 0.6062 - accuracy: 0.8510 - val_loss: 1.0171 - val_accuracy: 0.7111
#
# Epoch 00011: val_loss improved from 1.03878 to 1.01712, saving model to history/resnet50_aug.keras
# Epoch 12/50
# 1500/1500 [==============================] - 246s 164ms/step - loss: 0.5198 - accuracy: 0.8774 - val_loss: 0.9936 - val_accuracy: 0.7136
#
# Epoch 00012: val_loss improved from 1.01712 to 0.99364, saving model to history/resnet50_aug.keras
# Epoch 13/50
# 1500/1500 [==============================] - 244s 162ms/step - loss: 0.4734 - accuracy: 0.8891 - val_loss: 1.0194 - val_accuracy: 0.7083
#
# Epoch 00013: val_loss did not improve from 0.99364
# Epoch 14/50
# 1500/1500 [==============================] - 245s 163ms/step - loss: 0.4222 - accuracy: 0.9018 - val_loss: 1.0292 - val_accuracy: 0.7046
#
# Epoch 00014: val_loss did not improve from 0.99364
# Epoch 15/50
# 1500/1500 [==============================] - 244s 163ms/step - loss: 0.3860 - accuracy: 0.9091 - val_loss: 1.0079 - val_accuracy: 0.7088
#
# Epoch 00015: val_loss did not improve from 0.99364
# Epoch 16/50
# 1500/1500 [==============================] - 248s 166ms/step - loss: 0.3468 - accuracy: 0.9190 - val_loss: 1.0038 - val_accuracy: 0.7079
#
# Epoch 00016: val_loss did not improve from 0.99364
# Epoch 17/50
# 1500/1500 [==============================] - 249s 166ms/step - loss: 0.3138 - accuracy: 0.9274 - val_loss: 1.0020 - val_accuracy: 0.7102
#
# Epoch 00017: val_loss did not improve from 0.99364
# Epoch 18/50
# 1500/1500 [==============================] - 251s 168ms/step - loss: 0.2899 - accuracy: 0.9328 - val_loss: 0.9920 - val_accuracy: 0.7133
#
# Epoch 00018: val_loss improved from 0.99364 to 0.99201, saving model to history/resnet50_aug.keras
# Epoch 19/50
# 1500/1500 [==============================] - 244s 163ms/step - loss: 0.2670 - accuracy: 0.9414 - val_loss: 1.0138 - val_accuracy: 0.7062
#
# Epoch 00019: val_loss did not improve from 0.99201
# Epoch 20/50
# 1500/1500 [==============================] - 252s 168ms/step - loss: 0.2448 - accuracy: 0.9455 - val_loss: 1.0077 - val_accuracy: 0.7133
#
# Epoch 00020: val_loss did not improve from 0.99201
# Epoch 21/50
# 1500/1500 [==============================] - 246s 164ms/step - loss: 0.2161 - accuracy: 0.9546 - val_loss: 0.9924 - val_accuracy: 0.7176
#
# Epoch 00021: val_loss did not improve from 0.99201
# Epoch 22/50
# 1500/1500 [==============================] - 251s 167ms/step - loss: 0.2049 - accuracy: 0.9560 - val_loss: 1.0262 - val_accuracy: 0.7059
#
# Epoch 00022: val_loss did not improve from 0.99201
# Epoch 23/50
# 1500/1500 [==============================] - 256s 170ms/step - loss: 0.1941 - accuracy: 0.9593 - val_loss: 1.0113 - val_accuracy: 0.7098
#
# Epoch 00023: val_loss did not improve from 0.99201
# Epoch 24/50
# 1500/1500 [==============================] - 254s 169ms/step - loss: 0.1715 - accuracy: 0.9668 - val_loss: 1.0141 - val_accuracy: 0.7087
#
# Epoch 00024: val_loss did not improve from 0.99201
# Epoch 25/50
# 1500/1500 [==============================] - 259s 173ms/step - loss: 0.1653 - accuracy: 0.9660 - val_loss: 1.0137 - val_accuracy: 0.7123
#
# Epoch 00025: val_loss did not improve from 0.99201
# Epoch 26/50
# 1500/1500 [==============================] - 248s 165ms/step - loss: 0.1466 - accuracy: 0.9718 - val_loss: 1.0076 - val_accuracy: 0.7105
#
# Epoch 00026: val_loss did not improve from 0.99201
# Epoch 27/50
# 1500/1500 [==============================] - 254s 169ms/step - loss: 0.1370 - accuracy: 0.9744 - val_loss: 1.0094 - val_accuracy: 0.7121
#
# Epoch 00027: val_loss did not improve from 0.99201
# Epoch 28/50
# 1500/1500 [==============================] - 246s 164ms/step - loss: 0.1258 - accuracy: 0.9780 - val_loss: 1.0153 - val_accuracy: 0.7100
#
# Epoch 00028: val_loss did not improve from 0.99201
# Epoch 29/50
# 1500/1500 [==============================] - 250s 167ms/step - loss: 0.1162 - accuracy: 0.9790 - val_loss: 1.0095 - val_accuracy: 0.7132
#
# Epoch 00029: val_loss did not improve from 0.99201
# Epoch 30/50
# 1500/1500 [==============================] - 243s 162ms/step - loss: 0.1080 - accuracy: 0.9820 - val_loss: 1.0235 - val_accuracy: 0.7102
#
# Epoch 00030: val_loss did not improve from 0.99201
# Epoch 31/50
# 1500/1500 [==============================] - 244s 163ms/step - loss: 0.0980 - accuracy: 0.9840 - val_loss: 1.0206 - val_accuracy: 0.7141
#
# Epoch 00031: val_loss did not improve from 0.99201
# Epoch 32/50
# 1500/1500 [==============================] - 251s 168ms/step - loss: 0.0954 - accuracy: 0.9842 - val_loss: 1.0178 - val_accuracy: 0.7151
#
# Epoch 00032: val_loss did not improve from 0.99201
# Epoch 33/50
# 1500/1500 [==============================] - 244s 163ms/step - loss: 0.0910 - accuracy: 0.9850 - val_loss: 1.0275 - val_accuracy: 0.7108
#
# Epoch 00033: val_loss did not improve from 0.99201
# Epoch 34/50
# 1500/1500 [==============================] - 252s 168ms/step - loss: 0.0838 - accuracy: 0.9874 - val_loss: 1.0412 - val_accuracy: 0.7073
#
# Epoch 00034: val_loss did not improve from 0.99201
# Epoch 35/50
# 1500/1500 [==============================] - 247s 165ms/step - loss: 0.0863 - accuracy: 0.9866 - val_loss: 1.0303 - val_accuracy: 0.7091
#
# Epoch 00035: val_loss did not improve from 0.99201
# Epoch 36/50
# 1500/1500 [==============================] - 252s 168ms/step - loss: 0.0690 - accuracy: 0.9904 - val_loss: 1.0600 - val_accuracy: 0.7030
#
# Epoch 00036: val_loss did not improve from 0.99201
# Epoch 37/50
# 1500/1500 [==============================] - 247s 165ms/step - loss: 0.0693 - accuracy: 0.9901 - val_loss: 1.0443 - val_accuracy: 0.7086
#
# Epoch 00037: val_loss did not improve from 0.99201
# Epoch 38/50
# 1500/1500 [==============================] - 249s 166ms/step - loss: 0.0654 - accuracy: 0.9901 - val_loss: 1.0440 - val_accuracy: 0.7073
#
# Epoch 00038: val_loss did not improve from 0.99201
# Epoch 39/50
# 1500/1500 [==============================] - 255s 170ms/step - loss: 0.0614 - accuracy: 0.9910 - val_loss: 1.0418 - val_accuracy: 0.7094
#
# Epoch 00039: val_loss did not improve from 0.99201
# Epoch 40/50
# 1500/1500 [==============================] - 259s 173ms/step - loss: 0.0569 - accuracy: 0.9923 - val_loss: 1.0469 - val_accuracy: 0.7052
#
# Epoch 00040: val_loss did not improve from 0.99201
# Epoch 41/50
# 1500/1500 [==============================] - 254s 169ms/step - loss: 0.0558 - accuracy: 0.9927 - val_loss: 1.0460 - val_accuracy: 0.7070
#
# Epoch 00041: val_loss did not improve from 0.99201
# Epoch 42/50
# 1500/1500 [==============================] - 253s 169ms/step - loss: 0.0519 - accuracy: 0.9928 - val_loss: 1.0526 - val_accuracy: 0.7060
#
# Epoch 00042: val_loss did not improve from 0.99201
# Epoch 43/50
# 1500/1500 [==============================] - 253s 168ms/step - loss: 0.0499 - accuracy: 0.9934 - val_loss: 1.0424 - val_accuracy: 0.7094
#
# Epoch 00043: val_loss did not improve from 0.99201
# Epoch 44/50
# 1500/1500 [==============================] - 249s 166ms/step - loss: 0.0617 - accuracy: 0.9895 - val_loss: 1.0565 - val_accuracy: 0.7087
#
# Epoch 00044: val_loss did not improve from 0.99201
# Epoch 45/50
# 1500/1500 [==============================] - 247s 165ms/step - loss: 0.0471 - accuracy: 0.9942 - val_loss: 1.0479 - val_accuracy: 0.7072
#
# Epoch 00045: val_loss did not improve from 0.99201
# Epoch 46/50
# 1500/1500 [==============================] - 271s 180ms/step - loss: 0.0544 - accuracy: 0.9917 - val_loss: 1.0621 - val_accuracy: 0.7069
#
# Epoch 00046: val_loss did not improve from 0.99201
# Epoch 47/50
# 1500/1500 [==============================] - 248s 165ms/step - loss: 0.0443 - accuracy: 0.9946 - val_loss: 1.0531 - val_accuracy: 0.7097
#
# Epoch 00047: val_loss did not improve from 0.99201
# Epoch 48/50
# 1500/1500 [==============================] - 249s 166ms/step - loss: 0.0374 - accuracy: 0.9959 - val_loss: 1.0552 - val_accuracy: 0.7098
#
# Epoch 00048: val_loss did not improve from 0.99201
# Epoch 49/50
# 1500/1500 [==============================] - 252s 168ms/step - loss: 0.0359 - accuracy: 0.9961 - val_loss: 1.0589 - val_accuracy: 0.7067
#
# Epoch 00049: val_loss did not improve from 0.99201
# Epoch 50/50
# 1500/1500 [==============================] - 246s 164ms/step - loss: 0.0353 - accuracy: 0.9958 - val_loss: 1.0567 - val_accuracy: 0.7109
#
# Epoch 00050: val_loss did not improve from 0.99201

# %%
with open('history/history_resnet50_aug_2.json', 'w') as f:
    pd.DataFrame(history_resnet50_aug_2.history).to_json(f)

# %%
del aug_resnet50

# %%
cutmix_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    metrics=['accuracy'],
)

history_resnet50_cutmix_2 = cutmix_resnet50.fit(
    ds_train_cutmix,
    steps_per_epoch=int(2*ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test_all,
    verbose=1,
    use_multiprocessing=True,
    callbacks=[checkpoint_cutmix]
)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 323s 203ms/step - loss: 4.1533 - accuracy: 0.1477 - val_loss: 2.4332 - val_accuracy: 0.4374
#
# Epoch 00001: val_loss improved from inf to 2.43322, saving model to history/resnet50_cutmix.keras
# Epoch 2/50
# 1500/1500 [==============================] - 288s 192ms/step - loss: 2.7558 - accuracy: 0.4432 - val_loss: 1.5191 - val_accuracy: 0.6079
#
# Epoch 00002: val_loss improved from 2.43322 to 1.51905, saving model to history/resnet50_cutmix.keras
# Epoch 3/50
# 1500/1500 [==============================] - 288s 192ms/step - loss: 2.2097 - accuracy: 0.5693 - val_loss: 1.2356 - val_accuracy: 0.6623
#
# Epoch 00003: val_loss improved from 1.51905 to 1.23559, saving model to history/resnet50_cutmix.keras
# Epoch 4/50
# 1500/1500 [==============================] - 289s 193ms/step - loss: 1.9141 - accuracy: 0.6524 - val_loss: 1.1095 - val_accuracy: 0.6892
#
# Epoch 00004: val_loss improved from 1.23559 to 1.10947, saving model to history/resnet50_cutmix.keras
# Epoch 5/50
# 1500/1500 [==============================] - 292s 195ms/step - loss: 1.7651 - accuracy: 0.6892 - val_loss: 1.0312 - val_accuracy: 0.7042
#
# Epoch 00005: val_loss improved from 1.10947 to 1.03116, saving model to history/resnet50_cutmix.keras
# Epoch 6/50
# 1500/1500 [==============================] - 303s 202ms/step - loss: 1.5891 - accuracy: 0.7459 - val_loss: 0.9740 - val_accuracy: 0.7179
#
# Epoch 00006: val_loss improved from 1.03116 to 0.97401, saving model to history/resnet50_cutmix.keras
# Epoch 7/50
# 1500/1500 [==============================] - 304s 203ms/step - loss: 1.4882 - accuracy: 0.7785 - val_loss: 0.9568 - val_accuracy: 0.7227
#
# Epoch 00007: val_loss improved from 0.97401 to 0.95678, saving model to history/resnet50_cutmix.keras
# Epoch 8/50
# 1500/1500 [==============================] - 294s 196ms/step - loss: 1.3960 - accuracy: 0.7942 - val_loss: 0.9509 - val_accuracy: 0.7260
#
# Epoch 00008: val_loss improved from 0.95678 to 0.95088, saving model to history/resnet50_cutmix.keras
# Epoch 9/50
# 1500/1500 [==============================] - 290s 193ms/step - loss: 1.3542 - accuracy: 0.8042 - val_loss: 0.9223 - val_accuracy: 0.7344
#
# Epoch 00009: val_loss improved from 0.95088 to 0.92228, saving model to history/resnet50_cutmix.keras
# Epoch 10/50
# 1500/1500 [==============================] - 291s 194ms/step - loss: 1.3021 - accuracy: 0.8220 - val_loss: 0.9286 - val_accuracy: 0.7322
#
# Epoch 00010: val_loss did not improve from 0.92228
# Epoch 11/50
# 1500/1500 [==============================] - 290s 193ms/step - loss: 1.2523 - accuracy: 0.8337 - val_loss: 0.9250 - val_accuracy: 0.7367
#
# Epoch 00011: val_loss did not improve from 0.92228
# Epoch 12/50
# 1133/1500 [=====================>........] - ETA: 44:02 - loss: 1.0442 - accuracy: 0.8668

# %%
with open('history/history_resnet50_cutmix_2.json', 'w') as f:
    pd.DataFrame(history_resnet50_cutmix_2.history).to_json(f)

# %%
del cutmix_resnet50

# %%
mixup_resnet50.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    metrics=['accuracy'],
)

history_resnet50_mixup_2 = mixup_resnet50.fit(
    ds_train_mixup,
    steps_per_epoch=int(2*ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=EPOCH,
    validation_data=ds_test_all,
    verbose=1,
    use_multiprocessing=True,
    callbacks=[checkpoint_mixup]
)

# %%
with open('history/history_resnet50_mixup_2.json', 'w') as f:
    pd.DataFrame(history_resnet50_mixup_2.history).to_json(f)

# %%
del resnet50_cutmix

# %%
import json
import matplotlib.pyplot as plt

# %%
with open('history/history_resnet50_2.json', 'r') as f:
    history_resnet50_2 = json.load(f)

# %%
with open('history/history_resnet50_aug_2.json', 'r') as f:
    history_resnet50_aug_2 = json.load(f)

# %%
history_resnet50_2 = history_conv(history_resnet50_2)
history_resnet50_aug_2 = history_conv(history_resnet50_aug_2)

# %%
plt.figure(figsize=(14, 5))

plt.subplot(121)
plt.plot(history_resnet50_2['loss'], 'r')
plt.plot(history_resnet50_2['val_loss'], 'b')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(122)
plt.plot(history_resnet50_2['accuracy'], 'r')
plt.plot(history_resnet50_2['val_accuracy'], 'b')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(14, 5))

plt.subplot(121)
plt.plot(history_resnet50_aug_2['loss'], 'r')
plt.plot(history_resnet50_aug_2['val_loss'], 'b')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(122)
plt.plot(history_resnet50_aug_2['accuracy'], 'r')
plt.plot(history_resnet50_aug_2['val_accuracy'], 'b')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# # 회고
#
# ### 진행 사항
#     - nol, aug, cutmix, mixup 데이터셋을 제작하였음
#     - 각 데이터 셋 별로 모델을 학습하고 결과를 확인하였음
#     - 각 데이터 셋 별로 Overfitting 경향을 확인하였음
#
# ### 진행 예정 사항
#     - 50 epoch에서의 학습을 계속 수행할 예정
#     - 100 epoch에서의 학습을 계속 수행할 예정 (조별 학습)
#         - 김서영님 : classic
#         - 김용석님 : cutmix
#         - 본    인 : mixup
#
#     - 100 epoch 학습을 수행한 모델을 이용하여, 외부 test 데이터 셋으로 모델 성능 검증을 수행할 예정
#         - 동일 폴더의 'make_test_data.ipynb' 파일로 데이터 셋 생성
#
# ### 확인된 사항
#     - classic 보다 처리를 한 데이터들이 더 좁은 train-val acc 간극을 만들어냄
#         - classic 25.76%
#         - augment 26.42%
#         - cutmix  17.89%
#         - mixup   16.38%
